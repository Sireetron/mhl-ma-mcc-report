# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# db_connection_url = f"postgresql://system:FJNCEHfV@10.10.10.200:5432/system
# conn = create_engine(db_connection_url)
database_url = 'postgresql://system:FJNCEHfV@10.10.10.200:5432/system'
conn = create_engine(database_url )
sql = "select * from server_info"
df_info = pd.read_sql_query(sql, conn)
df_info
# Out:
#             server_name    ip_address              hostname      server_type  \
# 0      360-Webserver-01   10.10.10.22    web1.bigdata.local   Virtual Server
# 1      360-Webserver-02   10.10.10.23    web2.bigdata.local   Virtual Server
# 2  Big Data Data node 1   10.10.10.14  cdhdn1.bigdata.local  Physical Server
# 3  Big Data Data Node 2   10.10.10.15  cdhdn2.bigdata.local  Physical Server
# 4  Big Data Data Node 3   10.10.10.16  cdhdn3.bigdata.local  Physical Server
# 5    CDH6-Master-Node-1  10.10.10.200  cdhmn1.bigdata.local   Virtual Server
#
#    operating_system             services_software  cpu_total cpu_unit  \
# 0  Ubuntu 20.04 LTS              Frontend , Nginx          8     core
# 1  Ubuntu 20.04 LTS              Frontend , Nginx          8     core
# 2        Centos 7.9              DataNode, Impala         24     core
# 3        Centos 7.9              DataNode, Impala         24     core
# 4        Centos 7.9              DataNode, Impala         24     core
# ...
